# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure



# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
import os
pwd = os.getcwd()

# %%
filepath = pwd + "/pogojypan.csv"
filepath
# Out:
# '/Users/Byldepest/Documents/JUPYTER/sammenhængpogo/pogojypan.csv'

# %%
First_import = pd.read_csv(filepath)
First_import
# Out:
#           Zone          Sample Date  Dataset  Moisture (Avg) (%)  \
# 0    Rep green  2017-03-06 06:59:49        1                 9.2
# 1     06 Green  2017-03-06 07:18:15        1                22.0
# 2     01 Green  2017-03-06 09:28:10        1                25.6
# 3     10 Green  2017-03-06 14:03:53        1                24.3
# 4    17 tee 57  2017-03-06 14:14:52        1                26.1
# ..         ...                  ...      ...                 ...
# 858   11 Green  2023-06-20 13:17:54        1                27.6
# 859   06 Green  2023-06-20 13:21:12        1                25.9
# 860   14 Green  2023-06-20 13:24:56        1                25.7
# 861   15 Green  2023-06-20 13:30:14        1                25.5
# 862   16 Green  2023-06-20 13:34:39        1                25.3
#
#      Moisture (Min) (%)  Moisture (Max) (%)  EC (Avg) (dS/m)  EC (Min) (dS/m)  \
# 0                     9                   9             0.04             0.04
# ...

# %%
df = pd.read_csv(r'/Users/Byldepest/Documents/JUPYTER/sammenhængpogo/pogojypan2.csv')

# %%
df
# Out:
#          Zone          Sample Date  Dataset  Moisture (Avg) (%)  \
# 0    06 Green  2017-03-06 07:18:15        1                22.0
# 1    01 Green  2017-03-06 09:28:10        1                25.6
# 2    10 Green  2017-03-06 14:03:53        1                24.3
# 3    01 Green  2017-03-16 14:02:02        1                22.3
# 4    01 Green  2017-03-21 13:34:03        1                25.8
# ..        ...                  ...      ...                 ...
# 742  11 Green  2023-06-20 13:17:54        1                27.6
# 743  06 Green  2023-06-20 13:21:12        1                25.9
# 744  14 Green  2023-06-20 13:24:56        1                25.7
# 745  15 Green  2023-06-20 13:30:14        1                25.5
# 746  16 Green  2023-06-20 13:34:39        1                25.3
#
#      Moisture (Min) (%)  Moisture (Max) (%)  EC (Avg) (dS/m)  EC (Min) (dS/m)  \
# 0                    22                  22             0.07             0.07
# ...

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,round(pct_missing*100)))
# Out:
# Zone - 0%
# Sample Date - 0%
# Dataset - 0%
# Moisture (Avg) (%) - 0%
# Moisture (Min) (%) - 0%
# Moisture (Max) (%) - 0%
# EC (Avg) (dS/m) - 0%
# EC (Min) (dS/m) - 0%
# EC (Max) (dS/m) - 0%
# Temperature (Avg) (°C) - 0%
# Temperature - Min (°C) - 0%
# Temperature (Max) (°C) - 0%
# Salinity Index (Avg) - 0%
# Salinity Index (Min) - 0%
# Salinity Index (Max) - 0%

# %%
print(df.dtypes)
# Out:
# Zone                       object
# Sample Date                object
# Dataset                     int64
# Moisture (Avg) (%)        float64
# Moisture (Min) (%)          int64
# Moisture (Max) (%)          int64
# EC (Avg) (dS/m)           float64
# EC (Min) (dS/m)           float64
# EC (Max) (dS/m)           float64
# Temperature (Avg) (°C)    float64
# Temperature - Min (°C)    float64
# Temperature (Max) (°C)    float64
# Salinity Index (Avg)      float64
# Salinity Index (Min)      float64
# Salinity Index (Max)      float64
# dtype: object

# %%
df.boxplot(column=['Salinity Index (Avg)'])
# Out:
# <Axes: >

# %%
df.boxplot(column=['Moisture (Avg) (%)'])
# Out:
# <Axes: >

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of          Zone          Sample Date  Dataset  Moisture (Avg) (%)  \
# 0    06 Green  2017-03-06 07:18:15        1                22.0
# 1    01 Green  2017-03-06 09:28:10        1                25.6
# 2    10 Green  2017-03-06 14:03:53        1                24.3
# 3    01 Green  2017-03-16 14:02:02        1                22.3
# 4    01 Green  2017-03-21 13:34:03        1                25.8
# ..        ...                  ...      ...                 ...
# 742  11 Green  2023-06-20 13:17:54        1                27.6
# 743  06 Green  2023-06-20 13:21:12        1                25.9
# 744  14 Green  2023-06-20 13:24:56        1                25.7
# 745  15 Green  2023-06-20 13:30:14        1                25.5
# 746  16 Green  2023-06-20 13:34:39        1                25.3
#
#      Moisture (Min) (%)  Moisture (Max) (%)  EC (Avg) (dS/m)  EC (Min) (dS/m)  \
# ...

# %%
df.sort_values(by=['Salinity Index (Avg)'], inplace=False, ascending=False)
# Out:
#          Zone          Sample Date  Dataset  Moisture (Avg) (%)  \
# 304  17 Green  2018-08-08 10:13:45        1                20.1
# 306  15 Green  2018-08-08 12:16:28        1                17.0
# 302  01 Green  2018-08-08 09:44:14        1                18.9
# 314  06 Green  2018-08-09 11:20:19        1                20.3
# 287  14 Green  2018-08-07 06:57:42        2                18.3
# ..        ...                  ...      ...                 ...
# 365  10 Green  2018-12-10 11:37:31        1                24.6
# 557  13 Green  2022-03-11 12:52:56        1                22.6
# 0    06 Green  2017-03-06 07:18:15        1                22.0
# 556  17 Green  2022-03-11 12:49:48        1                20.9
# 104  01 Green  2017-07-12 13:10:10        1                 0.0
#
#      Moisture (Min) (%)  Moisture (Max) (%)  EC (Avg) (dS/m)  EC (Min) (dS/m)  \
# 304                  12                  36             0.62             0.27
# ...

# %%
df.columns
# Out:
# Index(['Zone', 'Sample Date', 'Dataset', 'Moisture (Avg) (%)',
#        'Moisture (Min) (%)', 'Moisture (Max) (%)', 'EC (Avg) (dS/m)',
#        'EC (Min) (dS/m)', 'EC (Max) (dS/m)', 'Temperature (Avg) (°C)',
#        'Temperature - Min (°C)', 'Temperature (Max) (°C)',
#        'Salinity Index (Avg)', 'Salinity Index (Min)', 'Salinity Index (Max)'],
#       dtype='object')

# %%
sns.regplot(x="Moisture (Avg) (%)", y="Salinity Index (Avg)", data=df, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='Moisture (Avg) (%)', ylabel='Salinity Index (Avg)'>

# %%
sns.regplot(x="Temperature (Avg) (°C)",y="Salinity Index (Avg)", data=df, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='Temperature (Avg) (°C)', ylabel='Salinity Index (Avg)'>

# %%
# Alt det under gør man til at starte med når man importere dataen. 
#Det koster mega meget tid hvis den næste analyse ikke forstår værdigerne fordi tal og skrift er blandet sammen
#evt brug 
#numeric_columns = df.select_dtypes(include='number')
#correlation = numeric_columns.corr(method='pearson')

# %%
new_columns = df['Zone'].str.split(' ',expand=True)

# %%
df = pd.concat([df,new_columns], axis=1)

# %%
new_columns = new_columns.rename (columns={0:'Hul', 1: 'Area'})

# %%
df = df.drop(['Zone'], axis=1)

# %%
new_columns = df['Sample Date'].str.split(' ',expand=True)

# %%
new_columns = new_columns.rename(columns={0:'Sample dag', 1:'Sample tid'})

# %%
df = pd.concat([df,new_columns], axis=1)

# %%
df = df.drop(['Sample Date'], axis=1)

# %%
df = df.drop(['Area'], axis=1)

# %%
df['Sample dag'] = pd.to_datetime(df['Sample dag'])

# %%
df['Sample tid'] = pd.to_timedelta(df['Sample tid'])

# %%
df= df.drop(['Dataset'], axis=1)

# %%
df
# Out:
#      Moisture (Avg) (%)  Moisture (Min) (%)  Moisture (Max) (%)  \
# 0                  22.0                  22                  22
# 1                  25.6                  18                  43
# 2                  24.3                  21                  29
# 3                  22.3                  12                  32
# 4                  25.8                  19                  34
# ..                  ...                 ...                 ...
# 742                27.6                  23                  37
# 743                25.9                  17                  35
# 744                25.7                  14                  32
# 745                25.5                  19                  33
# 746                25.3                  17                  33
#
#      EC (Avg) (dS/m)  EC (Min) (dS/m)  EC (Max) (dS/m)  \
# 0               0.07             0.07             0.07
# 1               0.12             0.06             0.26
# ...

# %%
df.corr(method='pearson')
# Out:
#                         Moisture (Avg) (%)  Moisture (Min) (%)  \
# Moisture (Avg) (%)                1.000000            0.798224
# Moisture (Min) (%)                0.798224            1.000000
# Moisture (Max) (%)                0.489431            0.222596
# EC (Avg) (dS/m)                   0.168328           -0.014852
# EC (Min) (dS/m)                   0.293901            0.359580
# EC (Max) (dS/m)                   0.083593           -0.139801
# Temperature (Avg) (°C)           -0.309556           -0.267117
# Temperature - Min (°C)           -0.275314           -0.188463
# Temperature (Max) (°C)           -0.307735           -0.275832
# Salinity Index (Avg)             -0.211318           -0.309095
# Salinity Index (Min)             -0.246576           -0.271500
# Salinity Index (Max)             -0.178842           -0.309515
# Hul                               0.007144            0.050315
# Sample dag                        0.291691            0.058357
# ...

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix,annot=True)

plt.title("Correlation between pogodata for Royal Golf CPH")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# Moisture (Avg) (%)  Moisture (Avg) (%)      1.000000
#                     Moisture (Min) (%)      0.232821
#                     Moisture (Max) (%)      0.192889
#                     EC (Avg) (dS/m)         0.123809
#                     EC (Min) (dS/m)         0.057772
#                                               ...
# Sample tid          Salinity Index (Min)    0.205032
#                     Salinity Index (Max)    0.484188
#                     Hul                     0.060218
#                     Sample dag              0.974666
#                     Sample tid              1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# EC (Min) (dS/m)     Moisture (Min) (%)     -0.130433
# Moisture (Min) (%)  EC (Min) (dS/m)        -0.130433
#                     EC (Avg) (dS/m)        -0.087045
# EC (Avg) (dS/m)     Moisture (Min) (%)     -0.087045
# Moisture (Min) (%)  Salinity Index (Max)   -0.076206
#                                               ...
# EC (Avg) (dS/m)     EC (Avg) (dS/m)         1.000000
# Moisture (Max) (%)  Moisture (Max) (%)      1.000000
# Moisture (Min) (%)  Moisture (Min) (%)      1.000000
# Sample dag          Sample dag              1.000000
# Sample tid          Sample tid              1.000000
# Length: 225, dtype: float64

# %%
strong_pairs = sorted_pairs[abs(sorted_pairs) >0.5]

print(strong_pairs)
# Out:
# Salinity Index (Avg)    EC (Avg) (dS/m)           0.500481
# EC (Avg) (dS/m)         Salinity Index (Avg)      0.500481
# Salinity Index (Avg)    EC (Max) (dS/m)           0.527245
# EC (Max) (dS/m)         Salinity Index (Avg)      0.527245
# Temperature (Avg) (°C)  Sample tid                0.547872
# Sample tid              Temperature (Avg) (°C)    0.547872
# Salinity Index (Max)    Salinity Index (Avg)      0.548286
# Salinity Index (Avg)    Salinity Index (Max)      0.548286
# EC (Avg) (dS/m)         Salinity Index (Max)      0.554780
# Salinity Index (Max)    EC (Avg) (dS/m)           0.554780
# Sample dag              Temperature (Avg) (°C)    0.579856
# Temperature (Avg) (°C)  Sample dag                0.579856
# EC (Avg) (dS/m)         EC (Min) (dS/m)           0.594151
# EC (Min) (dS/m)         EC (Avg) (dS/m)           0.594151
# Salinity Index (Max)    EC (Max) (dS/m)           0.649934
# EC (Max) (dS/m)         Salinity Index (Max)      0.649934
# ...

# %%
df
# Out:
#      Moisture (Avg) (%)  Moisture (Min) (%)  Moisture (Max) (%)  \
# 0                  22.0                  22                  22
# 1                  25.6                  18                  43
# 2                  24.3                  21                  29
# 3                  22.3                  12                  32
# 4                  25.8                  19                  34
# ..                  ...                 ...                 ...
# 742                27.6                  23                  37
# 743                25.9                  17                  35
# 744                25.7                  14                  32
# 745                25.5                  19                  33
# 746                25.3                  17                  33
#
#      EC (Avg) (dS/m)  EC (Min) (dS/m)  EC (Max) (dS/m)  \
# 0               0.07             0.07             0.07
# 1               0.12             0.06             0.26
# ...

# %%
df.boxplot(column=['Salinity Index (Max)'])
# Out:
# <Axes: >

# %%
sns.regplot(x='EC (Avg) (dS/m)', y='Salinity Index (Avg)', data=df, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='EC (Avg) (dS/m)', ylabel='Salinity Index (Avg)'>

# %%
sns.regplot(
    x = 'Temperature (Avg) (°C)',
    y = 'Moisture (Avg) (%)',
    data = df,
    line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='Temperature (Avg) (°C)', ylabel='Moisture (Avg) (%)'>

# %%
df = df.drop(['Sample tid'],axis=1)

# %%
df = df.drop(['Sample dag'],axis=1)

# %%
df = df.drop(['Hul'],axis=1)

# %%
df
# Out:
#      Moisture (Avg) (%)  Moisture (Min) (%)  Moisture (Max) (%)  \
# 0                  22.0                  22                  22
# 1                  25.6                  18                  43
# 2                  24.3                  21                  29
# 3                  22.3                  12                  32
# 4                  25.8                  19                  34
# ..                  ...                 ...                 ...
# 742                27.6                  23                  37
# 743                25.9                  17                  35
# 744                25.7                  14                  32
# 745                25.5                  19                  33
# 746                25.3                  17                  33
#
#      EC (Avg) (dS/m)  EC (Min) (dS/m)  EC (Max) (dS/m)  \
# 0               0.07             0.07             0.07
# 1               0.12             0.06             0.26
# ...

# %%
df.corr(method='pearson')
# Out:
#                         Moisture (Avg) (%)  Moisture (Min) (%)  \
# Moisture (Avg) (%)                1.000000            0.798224
# Moisture (Min) (%)                0.798224            1.000000
# Moisture (Max) (%)                0.489431            0.222596
# EC (Avg) (dS/m)                   0.168328           -0.014852
# EC (Min) (dS/m)                   0.293901            0.359580
# EC (Max) (dS/m)                   0.083593           -0.139801
# Temperature (Avg) (°C)           -0.309556           -0.267117
# Temperature - Min (°C)           -0.275314           -0.188463
# Temperature (Max) (°C)           -0.307735           -0.275832
# Salinity Index (Avg)             -0.211318           -0.309095
# Salinity Index (Min)             -0.246576           -0.271500
# Salinity Index (Max)             -0.178842           -0.309515
#
#                         Moisture (Max) (%)  EC (Avg) (dS/m)  EC (Min) (dS/m)  \
# ...

# %%
correlation_matrix = df.corr()

sns.heatmap (correlation_matrix,annot=True)

plt.title("Correlation 2 reduceret")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
